# %%
# !pip install seaborn
# Out:
# ...
#      ------------------------------------ 288.2/288.2 kB 171.1 kB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_excel('titanic.xls')
print(pd.options.display.max_rows)
sns.boxplot(x='survived',y='age',data=df)
# Out:
# 60
# <AxesSubplot: xlabel='survived', ylabel='age'>

# %%
df.hist()
plt.show()

# %%
df_copy=df.copy()

# %%
df_copy.drop(df_copy[df_copy['age']>50]['age'].index,inplace=True)

# %%
df_copy.shape
# Out:
# (1214, 14)

# %%
def ages (age):
    if age<50:
        return "adult"
    else:
        return "elder"
df_copy['new_age']=df_copy['age'].apply(ages)
df_copy.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest new_age
# ...

# %%
key=["name","age","city"]
val=["roaa",21,"tubas"]
ser1=pd.Series(data=val,index=key)
ser2=pd.Series(data=val)
ser1+ser2
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# age     NaN
# city    NaN
# name    NaN
# dtype: object

# %%
import numpy as np
from numpy.random import randn
df1=pd.DataFrame(randn(3,2),index=['x','y','z'],columns=['c1','c2'])
np.random.seed(34556)
df1
# Out:
#          c1        c2
# x -1.934066  0.615232
# y -0.446047 -0.202331
# z  1.011388 -0.315002

# %%
df2=df1[(df1['c1']<0) & (df1['c2']>0)]
df2
# Out:
#          c1        c2
# x -1.934066  0.615232

# %%
df3=pd.DataFrame([[1,2,3],
                  [4,5,6],
                  [7,8,]
    
]
                 ,index=['x','y','z'],
                 columns=['c1','c2','c3']
)

# %%
df3
# Out:
#    c1  c2   c3
# x   1   2  3.0
# y   4   5  6.0
# z   7   8  NaN

# %%
df3.dropna()
# Out:
#    c1  c2   c3
# x   1   2  3.0
# y   4   5  6.0

# %%
df3.fillna(55)
# Out:
#    c1  c2    c3
# x   1   2   3.0
# y   4   5   6.0
# z   7   8  55.0
